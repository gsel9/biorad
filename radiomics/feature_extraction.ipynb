# %% [markdown]
# # Radiomics Feature Extraction
#
# Extracting features from PET and CT images.

# %%
import nrrd
import utils
import ioutil

import numpy as np
import pandas as pd

from feature_extraction import feature_extractor

# %%
# Path to images.
path_ct_imagedir = './../../../data/source/raw_images/ct_cropped/'
path_pet_imagedir = './../../../data/source/raw_images/pet_cropped/'
path_masksdir = './../../../data/source/raw_images/masks_cropped/'

# %%
paths_ct_images = ioutil.sample_paths(
    path_ct_imagedir, path_masksdir, target_format='nrrd'
)
paths_pet_images = ioutil.sample_paths(
    path_pet_imagedir, path_masksdir, target_format='nrrd'
)

# %% [markdown]
# ## Bin Width
#
# PET and CT bin widths for histogram and image quantification.

# %%
utils.bin_width(paths_ct_images, 130)
# Out:
# 12.030159642370972

# %%
utils.bin_width(paths_pet_images, 64)
# Out:
# 0.2058715146898671

# %% [markdown]
# ## Computing features

# %%
_ = feature_extractor(
    './parameter_files/no_filtering/ct_130_config.yaml', 
    paths_ct_images, 
    verbose=1, 
    path_to_results='./../../../data/radiomics_features/no_filtering/ct_130.csv'
)
# Out:
# Initiated feature extraction.
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   20.5s
# [Parallel(n_jobs=3)]: Done 198 out of 198 | elapsed:  1.3min finished

# %%
_ = feature_extractor(
    './parameter_files/no_filtering/pet_64_config.yaml', 
    paths_pet_images, 
    verbose=1, 
    path_to_results='./../../../data/radiomics_features/no_filtering/pet_64.csv'
)
# Out:
# [Parallel(n_jobs=3)]: Using backend LokyBackend with 3 concurrent workers.
# Initiated feature extraction.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=3)]: Done 198 out of 198 | elapsed:  1.3min finished
# [OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P002PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P002mask.nrrd'),
#               ('Patient', 2),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.73888201976968),
#               ('original_shape_Flatness', 0.7239253889917328),
#               ('original_shape_LeastAxis', 27.06052891133134),
#               ('original_shape_MajorAxis', 37.38027333040584),
#               ('original_shape_Maximum2DDiameterColumn', 41.97618372363071),
#               ('original_shape_Maximum2DDiameterRow', 44.598206241955516),
#               ('original_shape_Maximum2DDiameterSlice', 42.720018726587654),
#               ('original_shape_Maximum3DDiameter', 45.617978911828175),
#               ('original_shape_MinorAxis', 27.619611857912968),
#               ('original_shape_Sphericity', 0.661531512608995),
#               ('original_shape_SurfaceArea', 4860.055715194758),
#               ('original_shape_SurfaceVolumeRatio', 0.2835174259243238),
#               ('original_shape_Volume', 17142.0),
#               ('original_firstorder_10Percentile', 0.3519366656709187),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 93248.06633165701),
#               ('original_firstorder_Entropy', 2.9660750035126786),
#               ('original_firstorder_InterquartileRange', 2.0233072834924037),
#               ('original_firstorder_Kurtosis', 1.7976698418580914),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                1.0089448841452413),
#               ('original_firstorder_Mean', 2.051787661713443),
#               ('original_firstorder_Median', 2.835852256050711),
#               ('original_firstorder_Minimum', -0.42646283977120847),
#               ('original_firstorder_Range', 3.4264628397712085),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.8414126202799115),
#               ('original_firstorder_RootMeanSquared', 2.332325561138385),
#               ('original_firstorder_Skewness', -0.6285826558389724),
#               ('original_firstorder_TotalEnergy', 93248.06633165701),
#               ('original_firstorder_Uniformity', 0.264183505328963),
#               ('original_firstorder_Variance', 1.2299099143799646),
#               ('original_glcm_Autocorrelation', 218.03824845483044),
#               ('original_glcm_ClusterProminence', 22288.470202661996),
#               ('original_glcm_ClusterShade', -828.5461011318881),
#               ('original_glcm_ClusterTendency', 103.90512191963727),
#               ('original_glcm_Contrast', 2.186632206580925),
#               ('original_glcm_Correlation', 0.9584394907731225),
#               ('original_glcm_DifferenceAverage', 0.7797669044117745),
#               ('original_glcm_DifferenceEntropy', 1.7079570453661823),
#               ('original_glcm_DifferenceVariance', 1.5530150840507224),
#               ('original_glcm_Id', 0.7614586065811875),
#               ('original_glcm_Idm', 0.7328458655082442),
#               ('original_glcm_Idmn', 0.993543852219469),
#               ('original_glcm_Idn', 0.9623365756592358),
#               ('original_glcm_Imc1', -0.4863702986231805),
#               ('original_glcm_Imc2', 0.9663635910110346),
#               ('original_glcm_InverseVariance', 0.20929140923884978),
#               ('original_glcm_JointAverage', 13.877503979958494),
#               ('original_glcm_JointEnergy', 0.2481291274568051),
#               ('original_glcm_JointEntropy', 4.310340106916865),
#               ('original_glcm_MaximumProbability', 0.49443609792127874),
#               ('original_glcm_SumAverage', 27.755007959916988),
#               ('original_glcm_SumEntropy', 3.491082919686308),
#               ('original_glcm_SumSquares', 26.522938531554544),
#               ('original_glrlm_GrayLevelNonUniformity', 509.5792108793629),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.06734468650298196),
#               ('original_glrlm_GrayLevelVariance', 21.305290327826754),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 130.17368839119078),
#               ('original_glrlm_LongRunEmphasis', 17.357569603412273),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                5116.295948314776),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.11996688080166384),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.0217210769995997),
#               ('original_glrlm_RunEntropy', 5.1860704267976505),
#               ('original_glrlm_RunLengthNonUniformity', 4238.1575427366715),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.5576975601209762),
#               ('original_glrlm_RunPercentage', 0.44074831946725546),
#               ('original_glrlm_RunVariance', 12.07823549543691),
#               ('original_glrlm_ShortRunEmphasis', 0.769676061736322),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                89.02147671869542),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.01597947691188079),
#               ('original_glszm_GrayLevelNonUniformity', 41.99173553719008),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.11567971222366413),
#               ('original_glszm_GrayLevelVariance', 13.468448572881329),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 192.34986225895318),
#               ('original_glszm_LargeAreaEmphasis', 208879.92837465566),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                65158355.23140496),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                867.6723132385171),
#               ('original_glszm_LowGrayLevelZoneEmphasis',
#                0.014591800201099922),
#               ('original_glszm_SizeZoneNonUniformity', 44.71349862258953),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.12317768215589403),
#               ('original_glszm_SmallAreaEmphasis', 0.3345302933734083),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                67.35798583404045),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.00394846285560203),
#               ('original_glszm_ZoneEntropy', 6.553433809571932),
#               ('original_glszm_ZonePercentage', 0.021176058802940146),
#               ('original_glszm_ZoneVariance', 206649.90337636322),
#               ('original_gldm_DependenceEntropy', 5.704896782734032),
#               ('original_gldm_DependenceNonUniformity', 2197.909928829775),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.12821782340624052),
#               ('original_gldm_DependenceVariance', 95.44086583437016),
#               ('original_gldm_GrayLevelNonUniformity', 4528.633648349084),
#               ('original_gldm_GrayLevelVariance', 28.73997107227119),
#               ('original_gldm_HighGrayLevelEmphasis', 209.2332866643332),
#               ('original_gldm_LargeDependenceEmphasis', 336.9493641348734),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                100400.53406837009),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                2.610036071440585),
#               ('original_gldm_LowGrayLevelEmphasis', 0.015765944601170003),
#               ('original_gldm_SmallDependenceEmphasis', 0.03413438161761382),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                5.519091671010632),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.00047493111219284523),
#               ('original_ngtdm_Busyness', 2.427090042396034),
#               ('original_ngtdm_Coarseness', 0.0012540262659497163),
#               ('original_ngtdm_Complexity', 48.302361156733404),
#               ('original_ngtdm_Contrast', 0.061504631434174076),
#               ('original_ngtdm_Strength', 0.45628547823124266),
#               ('label', None)]),
#  OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P004PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P004mask.nrrd'),
#               ('Patient', 4),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.7968997593943445),
#               ('original_shape_Flatness', 0.6299166579733464),
#               ('original_shape_LeastAxis', 19.845151130452972),
#               ('original_shape_MajorAxis', 31.504407574013833),
#               ('original_shape_Maximum2DDiameterColumn', 38.58756276314948),
#               ('original_shape_Maximum2DDiameterRow', 35.4682957019364),
#               ('original_shape_Maximum2DDiameterSlice', 29.410882339705484),
#               ('original_shape_Maximum3DDiameter', 38.704004960727254),
#               ('original_shape_MinorAxis', 25.105854815592988),
#               ('original_shape_Sphericity', 0.7017208821567033),
#               ('original_shape_SurfaceArea', 3126.0873705841627),
#               ('original_shape_SurfaceVolumeRatio', 0.32357803235525956),
#               ('original_shape_Volume', 9661.0),
#               ('original_firstorder_10Percentile', 0.03308188171391418),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 40446.52600905961),
#               ('original_firstorder_Entropy', 3.2996582178891085),
#               ('original_firstorder_InterquartileRange', 2.6331437385507206),
#               ('original_firstorder_Kurtosis', 1.3017977651237376),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                1.1649246781848244),
#               ('original_firstorder_Mean', 1.623906091219134),
#               ('original_firstorder_Median', 1.577295503760295),
#               ('original_firstorder_Minimum', -0.5083333552490872),
#               ('original_firstorder_Range', 3.5083333552490874),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                1.0885426037595147),
#               ('original_firstorder_RootMeanSquared', 2.046112797696749),
#               ('original_firstorder_Skewness', -0.06840660952681964),
#               ('original_firstorder_TotalEnergy', 40446.52600905961),
#               ('original_firstorder_Uniformity', 0.17286853438275263),
#               ('original_firstorder_Variance', 1.549506587799811),
#               ('original_glcm_Autocorrelation', 169.62492865437),
#               ('original_glcm_ClusterProminence', 26053.620669679607),
#               ('original_glcm_ClusterShade', -237.12271248136176),
#               ('original_glcm_ClusterTendency', 140.29473900736986),
#               ('original_glcm_Contrast', 2.6292143605345513),
#               ('original_glcm_Correlation', 0.9631234280269869),
#               ('original_glcm_DifferenceAverage', 0.8947701857088354),
#               ('original_glcm_DifferenceEntropy', 1.843037395841655),
#               ('original_glcm_DifferenceVariance', 1.7636609015711582),
#               ('original_glcm_Id', 0.7286056999759242),
#               ('original_glcm_Idm', 0.6983154152006568),
#               ('original_glcm_Idmn', 0.9922968749312192),
#               ('original_glcm_Idn', 0.9570084403616673),
#               ('original_glcm_Imc1', -0.4861732111651658),
#               ('original_glcm_Imc2', 0.9766827097184584),
#               ('original_glcm_InverseVariance', 0.2529670942283975),
#               ('original_glcm_JointAverage', 11.627711221915307),
#               ('original_glcm_JointEnergy', 0.13877662018816173),
#               ('original_glcm_JointEntropy', 4.922485578003146),
#               ('original_glcm_MaximumProbability', 0.3583357450212326),
#               ('original_glcm_SumAverage', 23.255422443830618),
#               ('original_glcm_SumEntropy', 4.000542384484121),
#               ('original_glcm_SumSquares', 35.7309883419761),
#               ('original_glrlm_GrayLevelNonUniformity', 344.5829607745237),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.07113575628957093),
#               ('original_glrlm_GrayLevelVariance', 24.204632726090356),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 110.2318757276844),
#               ('original_glrlm_LongRunEmphasis', 10.315062759474355),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                2587.655014334105),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.1637268265777014),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.03261807540682788),
#               ('original_glrlm_RunEntropy', 5.244146951169327),
#               ('original_glrlm_RunLengthNonUniformity', 2494.206641419438),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.5118573636337818),
#               ('original_glrlm_RunPercentage', 0.49860262912741954),
#               ('original_glrlm_RunVariance', 6.099988904311413),
#               ('original_glrlm_ShortRunEmphasis', 0.740422795583481),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                74.07364372895938),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.022396498577988293),
#               ('original_glszm_GrayLevelNonUniformity', 32.30379746835443),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.1022272071783368),
#               ('original_glszm_GrayLevelVariance', 12.964348662073386),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 180.3227848101266),
#               ('original_glszm_LargeAreaEmphasis', 48437.2753164557),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                13388319.015822785),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                492.6613246836022),
#               ('original_glszm_LowGrayLevelZoneEmphasis', 0.01820155426296935),
#               ('original_glszm_SizeZoneNonUniformity', 41.31012658227848),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.13072824867809646),
#               ('original_glszm_SmallAreaEmphasis', 0.3437712966466572),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                69.68184132193612),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.0029514687855983755),
#               ('original_glszm_ZoneEntropy', 6.453595748154644),
#               ('original_glszm_ZonePercentage', 0.032708829313735636),
#               ('original_glszm_ZoneVariance', 47502.58014540939),
#               ('original_gldm_DependenceEntropy', 6.572273621393436),
#               ('original_gldm_DependenceNonUniformity', 655.6189835420764),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.06786243489722352),
#               ('original_gldm_DependenceVariance', 79.6872215705845),
#               ('original_gldm_GrayLevelNonUniformity', 1670.082910671773),
#               ('original_gldm_GrayLevelVariance', 36.26690464547562),
#               ('original_gldm_HighGrayLevelEmphasis', 165.37304626850224),
#               ('original_gldm_LargeDependenceEmphasis', 276.70582755408344),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                70478.63813269848),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                4.8286876295424985),
#               ('original_gldm_LowGrayLevelEmphasis', 0.027937591914979538),
#               ('original_gldm_SmallDependenceEmphasis', 0.039891017414569706),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                6.131197118036747),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.0006150260183398318),
#               ('original_ngtdm_Busyness', 1.6586646099891547),
#               ('original_ngtdm_Coarseness', 0.0024160199684053847),
#               ('original_ngtdm_Complexity', 53.14032349811495),
#               ('original_ngtdm_Contrast', 0.08439620595609683),
#               ('original_ngtdm_Strength', 0.6975776694632546),
#               ('label', None)]),
#  OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P005PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P005mask.nrrd'),
#               ('Patient', 5),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.6009256176838577),
#               ('original_shape_Flatness', 0.5351398171521611),
#               ('original_shape_LeastAxis', 22.515071770938558),
#               ('original_shape_MajorAxis', 42.07325085761026),
#               ('original_shape_Maximum2DDiameterColumn', 46.06517122512408),
#               ('original_shape_Maximum2DDiameterRow', 43.01162633521314),
#               ('original_shape_Maximum2DDiameterSlice', 32.01562118716424),
#               ('original_shape_Maximum3DDiameter', 46.45427859734774),
#               ('original_shape_MinorAxis', 25.28289425957734),
#               ('original_shape_Sphericity', 0.7623652407384786),
#               ('original_shape_SurfaceArea', 4063.6330459812984),
#               ('original_shape_SurfaceVolumeRatio', 0.2506249565795793),
#               ('original_shape_Volume', 16214.0),
#               ('original_firstorder_10Percentile', 0.46872259638157854),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 97603.53830150628),
#               ('original_firstorder_Entropy', 2.803815176643969),
#               ('original_firstorder_InterquartileRange', 1.5836874797408724),
#               ('original_firstorder_Kurtosis', 2.458731133559535),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                0.9003587076451518),
#               ('original_firstorder_Mean', 2.2250045280032005),
#               ('original_firstorder_Median', 3.0),
#               ('original_firstorder_Minimum', -0.3790195280815162),
#               ('original_firstorder_Range', 3.3790195280815163),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.6802797952789944),
#               ('original_firstorder_RootMeanSquared', 2.4535092327709123),
#               ('original_firstorder_Skewness', -0.974781916708153),
#               ('original_firstorder_TotalEnergy', 97603.53830150628),
#               ('original_firstorder_Uniformity', 0.3089391961155295),
#               ('original_firstorder_Variance', 1.0690624056573659),
#               ('original_glcm_Autocorrelation', 207.31340324440464),
#               ('original_glcm_ClusterProminence', 22798.785392187754),
#               ('original_glcm_ClusterShade', -953.7311125538833),
#               ('original_glcm_ClusterTendency', 89.93242616152808),
#               ('original_glcm_Contrast', 2.166846357957925),
#               ('original_glcm_Correlation', 0.9525538040992654),
#               ('original_glcm_DifferenceAverage', 0.7816843203958576),
#               ('original_glcm_DifferenceEntropy', 1.6878210342199504),
#               ('original_glcm_DifferenceVariance', 1.5163761854965885),
#               ('original_glcm_Id', 0.7624790055153132),
#               ('original_glcm_Idm', 0.7318384081007842),
#               ('original_glcm_Idmn', 0.9928410403170195),
#               ('original_glcm_Idn', 0.9602765763086113),
#               ('original_glcm_Imc1', -0.4685374288210753),
#               ('original_glcm_Imc2', 0.9560369811792029),
#               ('original_glcm_InverseVariance', 0.19199233764366277),
#               ('original_glcm_JointAverage', 13.61488512247546),
#               ('original_glcm_JointEnergy', 0.2918555227995772),
#               ('original_glcm_JointEntropy', 4.100650828865472),
#               ('original_glcm_MaximumProbability', 0.5379291004442475),
#               ('original_glcm_SumAverage', 27.22977024495092),
#               ('original_glcm_SumEntropy', 3.275538120349702),
#               ('original_glcm_SumSquares', 23.024818129871502),
#               ('original_glrlm_GrayLevelNonUniformity', 457.46875311302335),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.06596613408126492),
#               ('original_glrlm_GrayLevelVariance', 21.706550178221814),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 123.43984891653584),
#               ('original_glrlm_LongRunEmphasis', 19.934837413894993),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                5384.956876716401),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.20305958425411838),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.0392778235909765),
#               ('original_glrlm_RunEntropy', 5.081139940940369),
#               ('original_glrlm_RunLengthNonUniformity', 4260.231967067517),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.608957764786034),
#               ('original_glrlm_RunPercentage', 0.4273419931493202),
#               ('original_glrlm_RunVariance', 14.227332903343058),
#               ('original_glrlm_ShortRunEmphasis', 0.7976424188999622),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                84.41872504624828),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.029728280074249994),
#               ('original_glszm_GrayLevelNonUniformity', 37.8235294117647),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.10113243158225857),
#               ('original_glszm_GrayLevelVariance', 12.063913752180504),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 156.44919786096256),
#               ('original_glszm_LargeAreaEmphasis', 211008.31016042782),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                60225686.898395725),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                927.5179763848838),
#               ('original_glszm_LowGrayLevelZoneEmphasis',
#                0.020740311685983368),
#               ('original_glszm_SizeZoneNonUniformity', 57.588235294117645),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.15397923875432526),
#               ('original_glszm_SmallAreaEmphasis', 0.3945050805937555),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                65.44355640864312),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.007172892223239084),
#               ('original_glszm_ZoneEntropy', 6.522878971916916),
#               ('original_glszm_ZonePercentage', 0.023066485753052916),
#               ('original_glszm_ZoneVariance', 209128.8326517773),
#               ('original_gldm_DependenceEntropy', 5.372721550774667),
#               ('original_gldm_DependenceNonUniformity', 2536.934007647712),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.15646564744342617),
#               ('original_gldm_DependenceVariance', 103.96932382535189),
#               ('original_gldm_GrayLevelNonUniformity', 5009.140125817195),
#               ('original_gldm_GrayLevelVariance', 24.982940137545125),
#               ('original_gldm_HighGrayLevelEmphasis', 201.0958430985568),
#               ('original_gldm_LargeDependenceEmphasis', 356.4330825212779),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                98773.06290859751),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                4.188225654678768),
#               ('original_gldm_LowGrayLevelEmphasis', 0.0270028912220372),
#               ('original_gldm_SmallDependenceEmphasis', 0.036831266896962964),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                5.047616757449751),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.0007954437855319005),
#               ('original_ngtdm_Busyness', 2.2975905686050817),
#               ('original_ngtdm_Coarseness', 0.0013323622539154235),
#               ('original_ngtdm_Complexity', 39.71580792023086),
#               ('original_ngtdm_Contrast', 0.05749920519724515),
#               ('original_ngtdm_Strength', 0.45034439843808355),
#               ('label', None)]),
#  OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P008PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P008mask.nrrd'),
#               ('Patient', 8),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.7845714331284448),
#               ('original_shape_Flatness', 0.414246798952065),
#               ('original_shape_LeastAxis', 30.263897332726067),
#               ('original_shape_MajorAxis', 73.05764923056914),
#               ('original_shape_Maximum2DDiameterColumn', 74.14849964766651),
#               ('original_shape_Maximum2DDiameterRow', 80.95677859203639),
#               ('original_shape_Maximum2DDiameterSlice', 65.76473218982953),
#               ('original_shape_Maximum3DDiameter', 83.43860018001261),
#               ('original_shape_MinorAxis', 57.31894455782285),
#               ('original_shape_Sphericity', 0.5200005354729174),
#               ('original_shape_SurfaceArea', 15698.615155160738),
#               ('original_shape_SurfaceVolumeRatio', 0.22635486280763528),
#               ('original_shape_Volume', 69354.0),
#               ('original_firstorder_10Percentile', -0.015165175981395041),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 252044.7870592925),
#               ('original_firstorder_Entropy', 3.7961003823497133),
#               ('original_firstorder_InterquartileRange', 2.3897813325217343),
#               ('original_firstorder_Kurtosis', 1.542487776906522),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                1.0259345631600747),
#               ('original_firstorder_Mean', 1.5208058696765745),
#               ('original_firstorder_Median', 1.4512235866056264),
#               ('original_firstorder_Minimum', -0.6015765641844998),
#               ('original_firstorder_Range', 3.6015765641844997),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.9462008959180825),
#               ('original_firstorder_RootMeanSquared', 1.9063520365332773),
#               ('original_firstorder_Skewness', -0.00740231124881746),
#               ('original_firstorder_TotalEnergy', 252044.7870592925),
#               ('original_firstorder_Uniformity', 0.09821090391188031),
#               ('original_firstorder_Variance', 1.3213275939518514),
#               ('original_glcm_Autocorrelation', 155.85518450552544),
#               ('original_glcm_ClusterProminence', 22736.42104993141),
#               ('original_glcm_ClusterShade', -143.15028971284502),
#               ('original_glcm_ClusterTendency', 120.8770033393341),
#               ('original_glcm_Contrast', 1.7566437637594143),
#               ('original_glcm_Correlation', 0.9713163924099751),
#               ('original_glcm_DifferenceAverage', 0.8353777182797596),
#               ('original_glcm_DifferenceEntropy', 1.761737470823326),
#               ('original_glcm_DifferenceVariance', 1.0247103352228235),
#               ('original_glcm_Id', 0.6979954128823018),
#               ('original_glcm_Idm', 0.6689417748846915),
#               ('original_glcm_Idmn', 0.9947182996028903),
#               ('original_glcm_Idn', 0.9583224056353523),
#               ('original_glcm_Imc1', -0.4984921240787679),
#               ('original_glcm_Imc2', 0.9869250298835899),
#               ('original_glcm_InverseVariance', 0.34850630489316237),
#               ('original_glcm_JointAverage', 11.228016140144138),
#               ('original_glcm_JointEnergy', 0.06565817215923389),
#               ('original_glcm_JointEntropy', 5.639293850989391),
#               ('original_glcm_MaximumProbability', 0.23558836047936957),
#               ('original_glcm_SumAverage', 22.456032280288273),
#               ('original_glcm_SumEntropy', 4.587897391792312),
#               ('original_glcm_SumSquares', 30.658411775773363),
#               ('original_glrlm_GrayLevelNonUniformity', 2346.1289008079366),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.061151936416420374),
#               ('original_glrlm_GrayLevelVariance', 20.954531897558375),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 114.70743596195035),
#               ('original_glrlm_LongRunEmphasis', 9.344738223449518),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                2225.1045514636276),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.19264360529921937),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.03196173628982319),
#               ('original_glrlm_RunEntropy', 5.347869700016653),
#               ('original_glrlm_RunLengthNonUniformity', 21561.928698300228),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.5543065875173679),
#               ('original_glrlm_RunPercentage', 0.5533261904920354),
#               ('original_glrlm_RunVariance', 5.907986048756073),
#               ('original_glrlm_ShortRunEmphasis', 0.7690557735793434),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                87.08159282743685),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.020920342384190875),
#               ('original_glszm_GrayLevelNonUniformity', 36.16465863453815),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.07261979645489589),
#               ('original_glszm_GrayLevelVariance', 20.66204174126224),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 146.2550200803213),
#               ('original_glszm_LargeAreaEmphasis', 881899.702811245),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                210350441.9257028),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                12475.092671534101),
#               ('original_glszm_LowGrayLevelZoneEmphasis', 0.03973096602602588),
#               ('original_glszm_SizeZoneNonUniformity', 67.98795180722891),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.13652199158078096),
#               ('original_glszm_SmallAreaEmphasis', 0.3508470798797323),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                53.717288778022535),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.00832822867334955),
#               ('original_glszm_ZoneEntropy', 7.038315535265254),
#               ('original_glszm_ZonePercentage', 0.007180551950860801),
#               ('original_glszm_ZoneVariance', 862504.9458073257),
#               ('original_gldm_DependenceEntropy', 7.215216093029678),
#               ('original_gldm_DependenceNonUniformity', 4510.459843700435),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.06503532375494471),
#               ('original_gldm_DependenceVariance', 67.08819627622543),
#               ('original_gldm_GrayLevelNonUniformity', 6811.319029904547),
#               ('original_gldm_GrayLevelVariance', 31.01165217075215),
#               ('original_gldm_HighGrayLevelEmphasis', 149.23345445107708),
#               ('original_gldm_LargeDependenceEmphasis', 226.1890590304813),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                51868.16421547424),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                6.311435806870547),
#               ('original_gldm_LowGrayLevelEmphasis', 0.03236996459977678),
#               ('original_gldm_SmallDependenceEmphasis', 0.026321769708547254),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                3.684029466049514),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.0005223500086778027),
#               ('original_ngtdm_Busyness', 9.430756637202817),
#               ('original_ngtdm_Coarseness', 0.0005762420446415036),
#               ('original_ngtdm_Complexity', 40.27582375354564),
#               ('original_ngtdm_Contrast', 0.06365408241100942),
#               ('original_ngtdm_Strength', 0.09886367170200851),
#               ('label', None)]),
#  OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P010PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P010mask.nrrd'),
#               ('Patient', 10),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.6903199869478472),
#               ('original_shape_Flatness', 0.5397428230463561),
#               ('original_shape_LeastAxis', 19.44980084452733),
#               ('original_shape_MajorAxis', 36.03531165963623),
#               ('original_shape_Maximum2DDiameterColumn', 33.28663395418648),
#               ('original_shape_Maximum2DDiameterRow', 38.01315561749642),
#               ('original_shape_Maximum2DDiameterSlice', 33.015148038438355),
#               ('original_shape_Maximum3DDiameter', 43.15089802078283),
#               ('original_shape_MinorAxis', 24.87589587454169),
#               ('original_shape_Sphericity', 0.6438221254727318),
#               ('original_shape_SurfaceArea', 3658.4484135770963),
#               ('original_shape_SurfaceVolumeRatio', 0.3403524433507393),
#               ('original_shape_Volume', 10749.0),
#               ('original_firstorder_10Percentile', 0.42693003295412496),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 42561.40826042096),
#               ('original_firstorder_Entropy', 3.796733958264559),
#               ('original_firstorder_InterquartileRange', 1.82301825084833),
#               ('original_firstorder_Kurtosis', 1.7709129107963162),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                0.8559920284811334),
#               ('original_firstorder_Mean', 1.7337229740341513),
#               ('original_firstorder_Median', 1.7036172890891899),
#               ('original_firstorder_Minimum', -0.4681106502880067),
#               ('original_firstorder_Range', 3.468110650288007),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.7661323226484777),
#               ('original_firstorder_RootMeanSquared', 1.989866603674878),
#               ('original_firstorder_Skewness', -0.12798608519901186),
#               ('original_firstorder_TotalEnergy', 42561.40826042096),
#               ('original_firstorder_Uniformity', 0.09184174369408485),
#               ('original_firstorder_Variance', 0.9537737497267712),
#               ('original_glcm_Autocorrelation', 174.08723285818874),
#               ('original_glcm_ClusterProminence', 12815.969797857235),
#               ('original_glcm_ClusterShade', -193.1152137397657),
#               ('original_glcm_ClusterTendency', 84.0689014937314),
#               ('original_glcm_Contrast', 2.099656454942745),
#               ('original_glcm_Correlation', 0.9511090237252708),
#               ('original_glcm_DifferenceAverage', 0.9751634889443784),
#               ('original_glcm_DifferenceEntropy', 1.8628943417583852),
#               ('original_glcm_DifferenceVariance', 1.097743941705509),
#               ('original_glcm_Id', 0.6548915237618874),
#               ('original_glcm_Idm', 0.6187088641325722),
#               ('original_glcm_Idmn', 0.9936853721598242),
#               ('original_glcm_Idn', 0.9514767469979766),
#               ('original_glcm_Imc1', -0.43955703914652544),
#               ('original_glcm_Imc2', 0.9778934438284433),
#               ('original_glcm_InverseVariance', 0.37269586081536665),
#               ('original_glcm_JointAverage', 12.39273523876221),
#               ('original_glcm_JointEnergy', 0.054303870405430096),
#               ('original_glcm_JointEntropy', 5.794181789681143),
#               ('original_glcm_MaximumProbability', 0.21336303045538374),
#               ('original_glcm_SumAverage', 24.78547047752442),
#               ('original_glcm_SumEntropy', 4.577732522697768),
#               ('original_glcm_SumSquares', 21.542139487168534),
#               ('original_glrlm_GrayLevelNonUniformity', 454.5793524300968),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.06724393917136248),
#               ('original_glrlm_GrayLevelVariance', 16.720097102516856),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 134.64543969589346),
#               ('original_glrlm_LongRunEmphasis', 5.4706246351874235),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                1275.6534041417658),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.06732935635360304),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.019129652377337193),
#               ('original_glrlm_RunEntropy', 5.023039132761626),
#               ('original_glrlm_RunLengthNonUniformity', 4220.185524472117),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.6162972222244605),
#               ('original_glrlm_RunPercentage', 0.6299190622383477),
#               ('original_glrlm_RunVariance', 2.8596853272492293),
#               ('original_glrlm_ShortRunEmphasis', 0.8080570438983596),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                104.66180548630693),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.014820993712678707),
#               ('original_glszm_GrayLevelNonUniformity', 11.718954248366012),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.07659447221154257),
#               ('original_glszm_GrayLevelVariance', 14.431201674569609),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 105.49019607843137),
#               ('original_glszm_LargeAreaEmphasis', 58768.08496732026),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                15006358.267973857),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                367.62615424036295),
#               ('original_glszm_LowGrayLevelZoneEmphasis',
#                0.029567080459323398),
#               ('original_glszm_SizeZoneNonUniformity', 16.77777777777778),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.10965867828612927),
#               ('original_glszm_SmallAreaEmphasis', 0.3197933049057942),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                35.980250867374544),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.00747293911351582),
#               ('original_glszm_ZoneEntropy', 6.435228039151307),
#               ('original_glszm_ZonePercentage', 0.014233882221602009),
#               ('original_glszm_ZoneVariance', 53832.33371780085),
#               ('original_gldm_DependenceEntropy', 7.172738826796898),
#               ('original_gldm_DependenceNonUniformity', 783.9466927156014),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.07293205811848558),
#               ('original_gldm_DependenceVariance', 60.51381412214008),
#               ('original_gldm_GrayLevelNonUniformity', 987.206902967718),
#               ('original_gldm_GrayLevelVariance', 22.454673523211035),
#               ('original_gldm_HighGrayLevelEmphasis', 164.29481812261605),
#               ('original_gldm_LargeDependenceEmphasis', 173.34291562005768),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                44559.77942134152),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                1.9250217649724974),
#               ('original_gldm_LowGrayLevelEmphasis', 0.01761830487808894),
#               ('original_gldm_SmallDependenceEmphasis', 0.03549394540420469),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                4.87505247126451),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.0006034916647791923),
#               ('original_ngtdm_Busyness', 1.6438707720288577),
#               ('original_ngtdm_Coarseness', 0.0029685249243412756),
#               ('original_ngtdm_Complexity', 51.761539152576304),
#               ('original_ngtdm_Contrast', 0.05726906163621031),
#               ('original_ngtdm_Strength', 0.473581038647706),
#               ('label', None)]),
#  OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P011PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P011mask.nrrd'),
#               ('Patient', 11),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.8415790956181016),
#               ('original_shape_Flatness', 0.3671089406802562),
#               ('original_shape_LeastAxis', 9.035962630788472),
#               ('original_shape_MajorAxis', 24.613845181881846),
#               ('original_shape_Maximum2DDiameterColumn', 25.238858928247925),
#               ('original_shape_Maximum2DDiameterRow', 23.259406699226016),
#               ('original_shape_Maximum2DDiameterSlice', 23.345235059857504),
#               ('original_shape_Maximum3DDiameter', 27.331300737432898),
#               ('original_shape_MinorAxis', 20.714497567852092),
#               ('original_shape_Sphericity', 0.7006495394010077),
#               ('original_shape_SurfaceArea', 1391.652643800184),
#               ('original_shape_SurfaceVolumeRatio', 0.48608195731756343),
#               ('original_shape_Volume', 2863.0),
#               ('original_firstorder_10Percentile', 0.7019251118804722),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 15729.828620328026),
#               ('original_firstorder_Entropy', 3.067082890338798),
#               ('original_firstorder_InterquartileRange', 1.6433458474276759),
#               ('original_firstorder_Kurtosis', 1.868228002288349),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation', 0.819858756800287),
#               ('original_firstorder_Mean', 2.157020121121027),
#               ('original_firstorder_Median', 2.468328954101098),
#               ('original_firstorder_Minimum', 0.02659584145412987),
#               ('original_firstorder_Range', 2.97340415854587),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.6881967892717635),
#               ('original_firstorder_RootMeanSquared', 2.3439660736363854),
#               ('original_firstorder_Skewness', -0.5854763172646777),
#               ('original_firstorder_TotalEnergy', 15729.828620328026),
#               ('original_firstorder_Uniformity', 0.21774713914714447),
#               ('original_firstorder_Variance', 0.8414411514374042),
#               ('original_glcm_Autocorrelation', 142.45403306962982),
#               ('original_glcm_ClusterProminence', 10455.796073947695),
#               ('original_glcm_ClusterShade', -408.208301297823),
#               ('original_glcm_ClusterTendency', 72.99640352203033),
#               ('original_glcm_Contrast', 2.1740168888861016),
#               ('original_glcm_Correlation', 0.9416786630045217),
#               ('original_glcm_DifferenceAverage', 0.8667422841712551),
#               ('original_glcm_DifferenceEntropy', 1.7955978991634844),
#               ('original_glcm_DifferenceVariance', 1.3581374141726619),
#               ('original_glcm_Id', 0.7180043242780829),
#               ('original_glcm_Idm', 0.6844215354833477),
#               ('original_glcm_Idmn', 0.990823658877279),
#               ('original_glcm_Idn', 0.9502263209473293),
#               ('original_glcm_Imc1', -0.44192327784099494),
#               ('original_glcm_Imc2', 0.9598648693865954),
#               ('original_glcm_InverseVariance', 0.2611317523989432),
#               ('original_glcm_JointAverage', 11.168729331066357),
#               ('original_glcm_JointEnergy', 0.182628413474579),
#               ('original_glcm_JointEntropy', 4.665247832773447),
#               ('original_glcm_MaximumProbability', 0.42145449829938464),
#               ('original_glcm_SumAverage', 22.337458662132715),
#               ('original_glcm_SumEntropy', 3.689333724910468),
#               ('original_glcm_SumSquares', 18.792605102729116),
#               ('original_glrlm_GrayLevelNonUniformity', 128.44005643428665),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.08178014046881568),
#               ('original_glrlm_GrayLevelVariance', 16.62515461016983),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 98.16472269436507),
#               ('original_glrlm_LongRunEmphasis', 7.256284179528887),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                1383.3226625511556),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.10840740826292437),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.038904100968102755),
#               ('original_glrlm_RunEntropy', 4.841534978143324),
#               ('original_glrlm_RunLengthNonUniformity', 872.4017020307037),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.5521527835934732),
#               ('original_glrlm_RunPercentage', 0.5470592976705445),
#               ('original_glrlm_RunVariance', 3.807309027508251),
#               ('original_glrlm_ShortRunEmphasis', 0.7645040808751821),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                62.09167164001984),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.03269191062701293),
#               ('original_glszm_GrayLevelNonUniformity', 10.43362831858407),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.09233299396977054),
#               ('original_glszm_GrayLevelVariance', 12.632312632156003),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 104.48672566371681),
#               ('original_glszm_LargeAreaEmphasis', 14996.53982300885),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                3211594.0619469024),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                95.78805942027186),
#               ('original_glszm_LowGrayLevelZoneEmphasis', 0.0359967018183875),
#               ('original_glszm_SizeZoneNonUniformity', 21.743362831858406),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.19241914010494165),
#               ('original_glszm_SmallAreaEmphasis', 0.447440270084074),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                48.03904300212081),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.009039249898321668),
#               ('original_glszm_ZoneEntropy', 5.6707314274658565),
#               ('original_glszm_ZonePercentage', 0.03946908836884387),
#               ('original_glszm_ZoneVariance', 14354.612577335734),
#               ('original_gldm_DependenceEntropy', 6.359936448927837),
#               ('original_gldm_DependenceNonUniformity', 194.75480265455815),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.06802473023211951),
#               ('original_gldm_DependenceVariance', 82.89868434745446),
#               ('original_gldm_GrayLevelNonUniformity', 623.4100593782746),
#               ('original_gldm_GrayLevelVariance', 19.65914813507615),
#               ('original_gldm_HighGrayLevelEmphasis', 139.50925602514843),
#               ('original_gldm_LargeDependenceEmphasis', 246.13657003143555),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                51533.18023052742),
# ...
#               ('Patient', 253),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.6288966504819079),
#               ('original_shape_Flatness', 0.4921930622499597),
#               ('original_shape_LeastAxis', 22.577088751891655),
#               ('original_shape_MajorAxis', 45.87039209509602),
#               ('original_shape_Maximum2DDiameterColumn', 47.4236228055175),
#               ('original_shape_Maximum2DDiameterRow', 44.64302857109943),
#               ('original_shape_Maximum2DDiameterSlice', 34.438350715445125),
#               ('original_shape_Maximum3DDiameter', 50.68530358989675),
#               ('original_shape_MinorAxis', 28.84773594489767),
#               ('original_shape_Sphericity', 0.7253989884429761),
#               ('original_shape_SurfaceArea', 4654.840016539744),
#               ('original_shape_SurfaceVolumeRatio', 0.2522948518449726),
#               ('original_shape_Volume', 18450.0),
#               ('original_firstorder_10Percentile', 0.7488082336784441),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 106187.6374136551),
#               ('original_firstorder_Entropy', 3.0470249755412078),
#               ('original_firstorder_InterquartileRange', 1.5598685775938737),
#               ('original_firstorder_Kurtosis', 2.274321581414716),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                0.8159699778781704),
#               ('original_firstorder_Mean', 2.2122533860171645),
#               ('original_firstorder_Median', 2.700202891230497),
#               ('original_firstorder_Minimum', -0.38291512576378756),
#               ('original_firstorder_Range', 3.3829151257637875),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.6502201923477274),
#               ('original_firstorder_RootMeanSquared', 2.3990472071418534),
#               ('original_firstorder_Skewness', -0.7998028174844538),
#               ('original_firstorder_TotalEnergy', 106187.6374136551),
#               ('original_firstorder_Uniformity', 0.237183827968361),
#               ('original_firstorder_Variance', 0.8613624581507193),
#               ('original_glcm_Autocorrelation', 201.87444271676137),
#               ('original_glcm_ClusterProminence', 13173.05997290189),
#               ('original_glcm_ClusterShade', -567.8068658469693),
#               ('original_glcm_ClusterTendency', 71.8887183432189),
#               ('original_glcm_Contrast', 1.8883790274643262),
#               ('original_glcm_Correlation', 0.9483928523265094),
#               ('original_glcm_DifferenceAverage', 0.8110258441707666),
#               ('original_glcm_DifferenceEntropy', 1.7277868137992323),
#               ('original_glcm_DifferenceVariance', 1.1920015373299855),
#               ('original_glcm_Id', 0.7290942620570715),
#               ('original_glcm_Idm', 0.6962295901616068),
#               ('original_glcm_Idmn', 0.9936662493915376),
#               ('original_glcm_Idn', 0.9579100273339951),
#               ('original_glcm_Imc1', -0.45308604553000364),
#               ('original_glcm_Imc2', 0.9609149961378012),
#               ('original_glcm_InverseVariance', 0.2510332264965819),
#               ('original_glcm_JointAverage', 13.578185235196027),
#               ('original_glcm_JointEnergy', 0.21261162627934355),
#               ('original_glcm_JointEntropy', 4.5065275562657545),
#               ('original_glcm_MaximumProbability', 0.4566951314931228),
#               ('original_glcm_SumAverage', 27.156370470392055),
#               ('original_glcm_SumEntropy', 3.5913668409314385),
#               ('original_glcm_SumSquares', 18.444274342670806),
#               ('original_glrlm_GrayLevelNonUniformity', 633.5236978205573),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.07021835345735473),
#               ('original_glrlm_GrayLevelVariance', 16.818461371573388),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 132.27117008785706),
#               ('original_glrlm_LongRunEmphasis', 14.747069769128656),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                3934.037643130873),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.09852198811730709),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.0227201670075889),
#               ('original_glrlm_RunEntropy', 4.937614434825457),
#               ('original_glrlm_RunLengthNonUniformity', 5783.519694284476),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.6348785177779985),
#               ('original_glrlm_RunPercentage', 0.4892682926829268),
#               ('original_glrlm_RunVariance', 10.420319292619684),
#               ('original_glrlm_ShortRunEmphasis', 0.8150798453323653),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                97.16870034417623),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.018670536327838768),
#               ('original_glszm_GrayLevelNonUniformity', 18.033816425120772),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.08711988611169455),
#               ('original_glszm_GrayLevelVariance', 18.4389834068473),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 141.68115942028984),
#               ('original_glszm_LargeAreaEmphasis', 378712.60869565216),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                105144286.85024154),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                1594.3078786059373),
#               ('original_glszm_LowGrayLevelZoneEmphasis', 0.03285241489280101),
#               ('original_glszm_SizeZoneNonUniformity', 30.835748792270532),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.14896497001096876),
#               ('original_glszm_SmallAreaEmphasis', 0.3812189450206502),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                54.483390392428355),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.007322728201769882),
#               ('original_glszm_ZoneEntropy', 6.271405304490219),
#               ('original_glszm_ZonePercentage', 0.01121951219512195),
#               ('original_glszm_ZoneVariance', 370768.3742911153),
#               ('original_gldm_DependenceEntropy', 5.707749041112409),
#               ('original_gldm_DependenceNonUniformity', 2371.088238482385),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.12851426766842194),
#               ('original_gldm_DependenceVariance', 100.3209529777249),
#               ('original_gldm_GrayLevelNonUniformity', 4376.04162601626),
#               ('original_gldm_GrayLevelVariance', 20.15165840438892),
#               ('original_gldm_HighGrayLevelEmphasis', 194.8641734417344),
#               ('original_gldm_LargeDependenceEmphasis', 304.21149051490517),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                84182.0068292683),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                1.8614784671947582),
#               ('original_gldm_LowGrayLevelEmphasis', 0.015988777105541623),
#               ('original_gldm_SmallDependenceEmphasis', 0.03322306522255633),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                4.580708846935958),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.0006194201694935856),
#               ('original_ngtdm_Busyness', 2.5766200097538765),
#               ('original_ngtdm_Coarseness', 0.0012782904967502564),
#               ('original_ngtdm_Complexity', 42.60420908518244),
#               ('original_ngtdm_Contrast', 0.04847040880316935),
#               ('original_ngtdm_Strength', 0.34895106667580345),
#               ('label', None)]),
#  OrderedDict([('Image',
#                './../../../data/source/raw_images/pet_cropped/P254PET.nrrd'),
#               ('Mask',
#                './../../../data/source/raw_images/masks_cropped/P254mask.nrrd'),
#               ('Patient', 254),
#               ('Reader', ''),
#               ('original_shape_Elongation', 0.8926365114506938),
#               ('original_shape_Flatness', 0.7562665902737054),
#               ('original_shape_LeastAxis', 22.96271820205261),
#               ('original_shape_MajorAxis', 30.363258799707154),
#               ('original_shape_Maximum2DDiameterColumn', 32.64965543462902),
#               ('original_shape_Maximum2DDiameterRow', 38.07886552931954),
#               ('original_shape_Maximum2DDiameterSlice', 32.449961479175904),
#               ('original_shape_Maximum3DDiameter', 38.54867053479276),
#               ('original_shape_MinorAxis', 27.103353411245173),
#               ('original_shape_Sphericity', 0.7240389491386383),
#               ('original_shape_SurfaceArea', 3552.4188729995044),
#               ('original_shape_SurfaceVolumeRatio', 0.2896151045980356),
#               ('original_shape_Volume', 12266.0),
#               ('original_firstorder_10Percentile', 1.466538654466922),
#               ('original_firstorder_90Percentile', 3.0),
#               ('original_firstorder_Energy', 89545.54845106952),
#               ('original_firstorder_Entropy', 2.0853886029224986),
#               ('original_firstorder_InterquartileRange', 0.5733573791019455),
#               ('original_firstorder_Kurtosis', 4.8810495047785585),
#               ('original_firstorder_Maximum', 3.0),
#               ('original_firstorder_MeanAbsoluteDeviation',
#                0.5258319941544966),
#               ('original_firstorder_Mean', 2.616748643696544),
#               ('original_firstorder_Median', 3.0),
#               ('original_firstorder_Minimum', -0.06681280697677629),
#               ('original_firstorder_Range', 3.066812806976776),
#               ('original_firstorder_RobustMeanAbsoluteDeviation',
#                0.29927344679323),
#               ('original_firstorder_RootMeanSquared', 2.7019077698653517),
#               ('original_firstorder_Skewness', -1.7219206715955748),
#               ('original_firstorder_TotalEnergy', 89545.54845106952),
#               ('original_firstorder_Uniformity', 0.4633042640406795),
#               ('original_firstorder_Variance', 0.45293213257105325),
#               ('original_glcm_Autocorrelation', 217.60955237519582),
#               ('original_glcm_ClusterProminence', 6957.507932946762),
#               ('original_glcm_ClusterShade', -391.83883328329256),
#               ('original_glcm_ClusterTendency', 33.68966197067516),
#               ('original_glcm_Contrast', 1.4606495435105304),
#               ('original_glcm_Correlation', 0.9152146882440564),
#               ('original_glcm_DifferenceAverage', 0.55766924116404),
#               ('original_glcm_DifferenceEntropy', 1.3659234411990355),
#               ('original_glcm_DifferenceVariance', 1.1363563327389614),
#               ('original_glcm_Id', 0.8259114978302289),
#               ('original_glcm_Idm', 0.803501144521925),
#               ('original_glcm_Idmn', 0.9945426598934822),
#               ('original_glcm_Idn', 0.96991719137084),
#               ('original_glcm_Imc1', -0.42851879081931304),
#               ('original_glcm_Imc2', 0.8895149160708111),
#               ('original_glcm_InverseVariance', 0.1441898458152844),
#               ('original_glcm_JointAverage', 14.475716631614542),
#               ('original_glcm_JointEnergy', 0.45808816881792924),
#               ('original_glcm_JointEntropy', 2.9421392211686554),
#               ('original_glcm_MaximumProbability', 0.6754730682319608),
#               ('original_glcm_SumAverage', 28.951433263229085),
#               ('original_glcm_SumEntropy', 2.3583442579833154),
#               ('original_glcm_SumSquares', 8.787577878546426),
#               ('original_glrlm_GrayLevelNonUniformity', 398.95667661838075),
#               ('original_glrlm_GrayLevelNonUniformityNormalized',
#                0.09364185279039863),
#               ('original_glrlm_GrayLevelVariance', 13.305178815585347),
#               ('original_glrlm_HighGrayLevelRunEmphasis', 145.04209321393859),
#               ('original_glrlm_LongRunEmphasis', 28.165256827037716),
#               ('original_glrlm_LongRunHighGrayLevelEmphasis',
#                7020.157079942724),
#               ('original_glrlm_LongRunLowGrayLevelEmphasis',
#                0.12853236546413588),
#               ('original_glrlm_LowGrayLevelRunEmphasis', 0.013946226498599059),
#               ('original_glrlm_RunEntropy', 4.802620394281154),
#               ('original_glrlm_RunLengthNonUniformity', 2418.614646370569),
#               ('original_glrlm_RunLengthNonUniformityNormalized',
#                0.5676114428293421),
#               ('original_glrlm_RunPercentage', 0.34663673192941086),
#               ('original_glrlm_RunVariance', 19.707357772650457),
#               ('original_glrlm_ShortRunEmphasis', 0.7677464081430246),
#               ('original_glrlm_ShortRunHighGrayLevelEmphasis',
#                95.23820341082693),
#               ('original_glrlm_ShortRunLowGrayLevelEmphasis',
#                0.01192758114959276),
#               ('original_glszm_GrayLevelNonUniformity', 26.81159420289855),
#               ('original_glszm_GrayLevelNonUniformityNormalized',
#                0.09714345725687881),
#               ('original_glszm_GrayLevelVariance', 11.324669187145556),
#               ('original_glszm_HighGrayLevelZoneEmphasis', 129.0),
#               ('original_glszm_LargeAreaEmphasis', 248980.28260869565),
#               ('original_glszm_LargeAreaHighGrayLevelEmphasis',
#                63567702.63768116),
#               ('original_glszm_LargeAreaLowGrayLevelEmphasis',
#                982.7705437540831),
#               ('original_glszm_LowGrayLevelZoneEmphasis',
#                0.018614139587251808),
#               ('original_glszm_SizeZoneNonUniformity', 34.55797101449275),
#               ('original_glszm_SizeZoneNonUniformityNormalized',
#                0.12521003990758245),
#               ('original_glszm_SmallAreaEmphasis', 0.34339421439680684),
#               ('original_glszm_SmallAreaHighGrayLevelEmphasis',
#                43.7237416353059),
#               ('original_glszm_SmallAreaLowGrayLevelEmphasis',
#                0.005707481562270162),
#               ('original_glszm_ZoneEntropy', 6.4889369111502715),
#               ('original_glszm_ZonePercentage', 0.02250122289254851),
#               ('original_glszm_ZoneVariance', 247005.18866834696),
#               ('original_gldm_DependenceEntropy', 4.502926632895503),
#               ('original_gldm_DependenceNonUniformity', 2599.1881624001303),
#               ('original_gldm_DependenceNonUniformityNormalized',
#                0.21190185573130038),
#               ('original_gldm_DependenceVariance', 102.33507798184857),
#               ('original_gldm_GrayLevelNonUniformity', 5682.890102722974),
#               ('original_gldm_GrayLevelVariance', 10.539707684614502),
#               ('original_gldm_HighGrayLevelEmphasis', 211.242621881624),
#               ('original_gldm_LargeDependenceEmphasis', 425.8832545247024),
#               ('original_gldm_LargeDependenceHighGrayLevelEmphasis',
#                107873.61715310614),
#               ('original_gldm_LargeDependenceLowGrayLevelEmphasis',
#                1.8026751438025324),
#               ('original_gldm_LowGrayLevelEmphasis', 0.00808265233537433),
#               ('original_gldm_SmallDependenceEmphasis', 0.033293841601835926),
#               ('original_gldm_SmallDependenceHighGrayLevelEmphasis',
#                4.493131542092614),
#               ('original_gldm_SmallDependenceLowGrayLevelEmphasis',
#                0.000459498492639665),
#               ('original_ngtdm_Busyness', 1.9423085730515668),
#               ('original_ngtdm_Coarseness', 0.0014171765495865128),
#               ('original_ngtdm_Complexity', 37.99173676526079),
#               ('original_ngtdm_Contrast', 0.025449281699870818),
#               ('original_ngtdm_Strength', 0.5753713822897146),
#               ('label', None)])]

# %% [markdown]
# # Postprocessing

# %%
true_index = np.load('./../../../data/source/patient_id.npy')

# %%
raw_ct = pd.read_csv(
    './../../../data/radiomics_features/no_filtering/ct_130.csv', 
    index_col=0
)
raw_ct.head()
# Out:
#                                                Image  \
# 0  ./../../../data/source/raw_images/ct_cropped/P...
# 1  ./../../../data/source/raw_images/ct_cropped/P...
# 2  ./../../../data/source/raw_images/ct_cropped/P...
# 3  ./../../../data/source/raw_images/ct_cropped/P...
# 4  ./../../../data/source/raw_images/ct_cropped/P...
#
#                                                 Mask  Patient  Reader  \
# 0  ./../../../data/source/raw_images/masks_croppe...        2     NaN
# 1  ./../../../data/source/raw_images/masks_croppe...        4     NaN
# 2  ./../../../data/source/raw_images/masks_croppe...        5     NaN
# 3  ./../../../data/source/raw_images/masks_croppe...        8     NaN
# 4  ./../../../data/source/raw_images/masks_croppe...       10     NaN
#
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.738882                 0.723925
# 1                   0.796900                 0.629917
# 2                   0.600926                 0.535140
# 3                   0.784571                 0.414247
# 4                   0.690320                 0.539743
#
#    original_shape_LeastAxis  original_shape_MajorAxis  \
# 0                 27.060529                 37.380273
# 1                 19.845151                 31.504408
# 2                 22.515072                 42.073251
# 3                 30.263897                 73.057649
# 4                 19.449801                 36.035312
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                               41.976184
# 1                               38.587563
# 2                               46.065171
# 3                               74.148500
# 4                               33.286634
#
#    original_shape_Maximum2DDiameterRow  ...    \
# 0                            44.598206  ...
# 1                            35.468296  ...
# 2                            43.011626  ...
# 3                            80.956779  ...
# 4                            38.013156  ...
#
#    original_gldm_LowGrayLevelEmphasis  original_gldm_SmallDependenceEmphasis  \
# 0                            0.270957                               0.003096
# 1                            0.668202                               0.005037
# 2                            0.367954                               0.003778
# 3                            0.312841                               0.003261
# 4                            0.994418                               0.002294
#
#    original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           0.008828
# 1                                           0.012243
# 2                                           0.009121
# 3                                           0.008661
# 4                                           0.002973
#
#    original_gldm_SmallDependenceLowGrayLevelEmphasis  original_ngtdm_Busyness  \
# 0                                           0.001663                52.686000
# 1                                           0.003236              1350.718517
# 2                                           0.002442               219.449851
# 3                                           0.001911               555.455131
# 4                                           0.002124                19.483858
#
#    original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# 0                   0.004953                   0.023557
# 1                   0.001131                   0.182981
# 2                   0.001491                   0.082733
# 3                   0.000515                   0.056019
# 4                   0.026248                   0.007089
#
#    original_ngtdm_Contrast  original_ngtdm_Strength  label
# 0                 0.000736                 0.004306    NaN
# 1                 0.045070                 0.001133    NaN
# 2                 0.011363                 0.001439    NaN
# 3                 0.004547                 0.000487    NaN
# 4                 0.000057                 0.024128    NaN
#
# [5 rows x 110 columns]

# %%
raw_pet = pd.read_csv(
    './../../../data/radiomics_features/no_filtering/pet_64.csv', 
    index_col=0
)
raw_pet.head()
# Out:
#                                                Image  \
# 0  ./../../../data/source/raw_images/pet_cropped/...
# 1  ./../../../data/source/raw_images/pet_cropped/...
# 2  ./../../../data/source/raw_images/pet_cropped/...
# 3  ./../../../data/source/raw_images/pet_cropped/...
# 4  ./../../../data/source/raw_images/pet_cropped/...
#
#                                                 Mask  Patient  Reader  \
# 0  ./../../../data/source/raw_images/masks_croppe...        2     NaN
# 1  ./../../../data/source/raw_images/masks_croppe...        4     NaN
# 2  ./../../../data/source/raw_images/masks_croppe...        5     NaN
# 3  ./../../../data/source/raw_images/masks_croppe...        8     NaN
# 4  ./../../../data/source/raw_images/masks_croppe...       10     NaN
#
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.738882                 0.723925
# 1                   0.796900                 0.629917
# 2                   0.600926                 0.535140
# 3                   0.784571                 0.414247
# 4                   0.690320                 0.539743
#
#    original_shape_LeastAxis  original_shape_MajorAxis  \
# 0                 27.060529                 37.380273
# 1                 19.845151                 31.504408
# 2                 22.515072                 42.073251
# 3                 30.263897                 73.057649
# 4                 19.449801                 36.035312
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                               41.976184
# 1                               38.587563
# 2                               46.065171
# 3                               74.148500
# 4                               33.286634
#
#    original_shape_Maximum2DDiameterRow  ...    \
# 0                            44.598206  ...
# 1                            35.468296  ...
# 2                            43.011626  ...
# 3                            80.956779  ...
# 4                            38.013156  ...
#
#    original_gldm_LowGrayLevelEmphasis  original_gldm_SmallDependenceEmphasis  \
# 0                            0.015766                               0.034134
# 1                            0.027938                               0.039891
# 2                            0.027003                               0.036831
# 3                            0.032370                               0.026322
# 4                            0.017618                               0.035494
#
#    original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# 0                                           5.519092
# 1                                           6.131197
# 2                                           5.047617
# 3                                           3.684029
# 4                                           4.875052
#
#    original_gldm_SmallDependenceLowGrayLevelEmphasis  original_ngtdm_Busyness  \
# 0                                           0.000475                 2.427090
# 1                                           0.000615                 1.658665
# 2                                           0.000795                 2.297591
# 3                                           0.000522                 9.430757
# 4                                           0.000603                 1.643871
#
#    original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# 0                   0.001254                  48.302361
# 1                   0.002416                  53.140323
# 2                   0.001332                  39.715808
# 3                   0.000576                  40.275824
# 4                   0.002969                  51.761539
#
#    original_ngtdm_Contrast  original_ngtdm_Strength  label
# 0                 0.061505                 0.456285    NaN
# 1                 0.084396                 0.697578    NaN
# 2                 0.057499                 0.450344    NaN
# 3                 0.063654                 0.098864    NaN
# 4                 0.057269                 0.473581    NaN
#
# [5 rows x 110 columns]

# %%
raw_ct.shape, raw_pet.shape
# Out:
# ((198, 110), (198, 110))

# %%
ct_feats, pet_feats = raw_ct.copy(), raw_pet.copy()

# %%
# Shape features are computed from image masks: PET and CT shape features are identical.
shape_features = raw_ct.filter(regex='shape')
shape_features.head()
# Out:
#    original_shape_Elongation  original_shape_Flatness  \
# 0                   0.738882                 0.723925
# 1                   0.796900                 0.629917
# 2                   0.600926                 0.535140
# 3                   0.784571                 0.414247
# 4                   0.690320                 0.539743
#
#    original_shape_LeastAxis  original_shape_MajorAxis  \
# 0                 27.060529                 37.380273
# 1                 19.845151                 31.504408
# 2                 22.515072                 42.073251
# 3                 30.263897                 73.057649
# 4                 19.449801                 36.035312
#
#    original_shape_Maximum2DDiameterColumn  \
# 0                               41.976184
# 1                               38.587563
# 2                               46.065171
# 3                               74.148500
# 4                               33.286634
#
#    original_shape_Maximum2DDiameterRow  original_shape_Maximum2DDiameterSlice  \
# 0                            44.598206                              42.720019
# 1                            35.468296                              29.410882
# 2                            43.011626                              32.015621
# 3                            80.956779                              65.764732
# 4                            38.013156                              33.015148
#
#    original_shape_Maximum3DDiameter  original_shape_MinorAxis  \
# 0                         45.617979                 27.619612
# 1                         38.704005                 25.105855
# 2                         46.454279                 25.282894
# 3                         83.438600                 57.318945
# 4                         43.150898                 24.875896
#
#    original_shape_Sphericity  original_shape_SurfaceArea  \
# 0                   0.661532                 4860.055715
# 1                   0.701721                 3126.087371
# 2                   0.762365                 4063.633046
# 3                   0.520001                15698.615155
# 4                   0.643822                 3658.448414
#
#    original_shape_SurfaceVolumeRatio  original_shape_Volume
# 0                           0.283517                17142.0
# 1                           0.323578                 9661.0
# 2                           0.250625                16214.0
# 3                           0.226355                69354.0
# 4                           0.340352                10749.0

# %%
shape_features.shape
# Out:
# (198, 13)

# %%
shape_features.index = true_index
shape_features.index.name = 'patient'

# %%
# Features extracted from filtered image.
ct_feats = ct_feats.filter(regex='original')
pet_feats = pet_feats.filter(regex='original')
ct_feats.shape, pet_feats.shape
# Out:
# ((198, 105), (198, 105))

# %%
105 - 13
# Out:
# 92

# %%
# Drop shape features from PET and CT data.
ct_feats.drop(list(shape_features.columns), inplace=True, axis=1)
pet_feats.drop(list(shape_features.columns), inplace=True, axis=1)
ct_feats.shape, pet_feats.shape
# Out:
# ((198, 92), (198, 92))

# %%
# Ensure unique identifiers on PET and CT features.
ct_feats.columns = ['CT {}'.format(label) for label in ct_feats.columns]
pet_feats.columns = ['PET {}'.format(label) for label in pet_feats.columns]

# %%
ct_feats.index = true_index
ct_feats.index.name = 'patient'
pet_feats.index = true_index
pet_feats.index.name = 'patient'
ct_feats.shape, pet_feats.shape
# Out:
# ((198, 92), (198, 92))

# %%
# Combine features sets (including PET params).
pet_params = pd.read_csv(
    './../../../data/to_analysis/pet_params.csv', index_col=0
)
pet_params.head()
# Out:
#            SUVpeak     MTV         TLG
# patient
# 2        21.616549   7.384  124.870726
# 4        15.296275   3.406   41.554406
# 5        14.473272   7.934   86.228420
# 8        10.510859  26.926  205.413389
# 10        7.213190   6.041   32.103770

# %%
pet_params.shape
# Out:
# (198, 3)

# %%
pet_params.columns = ['PET {}'.format(col) for col in pet_params.columns]
pet_params.head()
# Out:
#          PET SUVpeak  PET MTV     PET TLG
# patient
# 2          21.616549    7.384  124.870726
# 4          15.296275    3.406   41.554406
# 5          14.473272    7.934   86.228420
# 8          10.510859   26.926  205.413389
# 10          7.213190    6.041   32.103770

# %%
X = pd.concat((shape_features, ct_feats, pet_feats, pet_params), axis=1)
X.head()
# Out:
#          original_shape_Elongation  original_shape_Flatness  \
# patient
# 2                         0.738882                 0.723925
# 4                         0.796900                 0.629917
# 5                         0.600926                 0.535140
# 8                         0.784571                 0.414247
# 10                        0.690320                 0.539743
#
#          original_shape_LeastAxis  original_shape_MajorAxis  \
# patient
# 2                       27.060529                 37.380273
# 4                       19.845151                 31.504408
# 5                       22.515072                 42.073251
# 8                       30.263897                 73.057649
# 10                      19.449801                 36.035312
#
#          original_shape_Maximum2DDiameterColumn  \
# patient
# 2                                     41.976184
# 4                                     38.587563
# 5                                     46.065171
# 8                                     74.148500
# 10                                    33.286634
#
#          original_shape_Maximum2DDiameterRow  \
# patient
# 2                                  44.598206
# 4                                  35.468296
# 5                                  43.011626
# 8                                  80.956779
# 10                                 38.013156
#
#          original_shape_Maximum2DDiameterSlice  \
# patient
# 2                                    42.720019
# 4                                    29.410882
# 5                                    32.015621
# 8                                    65.764732
# 10                                   33.015148
#
#          original_shape_Maximum3DDiameter  original_shape_MinorAxis  \
# patient
# 2                               45.617979                 27.619612
# 4                               38.704005                 25.105855
# 5                               46.454279                 25.282894
# 8                               83.438600                 57.318945
# 10                              43.150898                 24.875896
#
#          original_shape_Sphericity     ...      \
# patient                                ...
# 2                         0.661532     ...
# 4                         0.701721     ...
# 5                         0.762365     ...
# 8                         0.520001     ...
# 10                        0.643822     ...
#
#          PET original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# patient
# 2                                                 5.519092
# 4                                                 6.131197
# 5                                                 5.047617
# 8                                                 3.684029
# 10                                                4.875052
#
#          PET original_gldm_SmallDependenceLowGrayLevelEmphasis  \
# patient
# 2                                                 0.000475
# 4                                                 0.000615
# 5                                                 0.000795
# 8                                                 0.000522
# 10                                                0.000603
#
#          PET original_ngtdm_Busyness  PET original_ngtdm_Coarseness  \
# patient
# 2                           2.427090                       0.001254
# 4                           1.658665                       0.002416
# 5                           2.297591                       0.001332
# 8                           9.430757                       0.000576
# 10                          1.643871                       0.002969
#
#          PET original_ngtdm_Complexity  PET original_ngtdm_Contrast  \
# patient
# 2                            48.302361                     0.061505
# 4                            53.140323                     0.084396
# 5                            39.715808                     0.057499
# 8                            40.275824                     0.063654
# 10                           51.761539                     0.057269
#
#          PET original_ngtdm_Strength  PET SUVpeak  PET MTV     PET TLG
# patient
# 2                           0.456285    21.616549    7.384  124.870726
# 4                           0.697578    15.296275    3.406   41.554406
# 5                           0.450344    14.473272    7.934   86.228420
# 8                           0.098864    10.510859   26.926  205.413389
# 10                          0.473581     7.213190    6.041   32.103770
#
# [5 rows x 200 columns]

# %%
X.shape
# Out:
# (198, 200)

# %%
X.filter(regex='CT').columns.size
# Out:
# 92

# %%
X.filter(regex='PET').columns.size
# Out:
# 95

# %%
X.filter(regex='shape').columns.size
# Out:
# 13

# %% [markdown]
# ### Redundat Features

# %%
redundant_cols = X.columns[X.var() == 0.0]
redundant_cols
# Out:
# Index([], dtype='object')

# %%
pd.Series(redundant_cols).to_csv(
    './../../../data/radiomics_features/no_filtering/errors/redundant.txt'
)
X.drop(redundant_cols, axis=1, inplace=True)

# %% [markdown]
# ### Missing Value Features

# %%
missing_value_cols = X.columns[X.isnull().any()]
missing_value_cols
# Out:
# Index(['CT original_ngtdm_Contrast'], dtype='object')

# %%
pd.Series(missing_value_cols).to_csv(
    './../../../data/radiomics_features/no_filtering/errors/missing_values.txt'
)
X.drop(missing_value_cols, axis=1, inplace=True)

# %%
X.to_csv('./../../../data/to_analysis/img_features.csv')
