# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Process Clinical Features

# %% [markdown]
# # Process Combined Features

# %%
img_feats = pd.read_csv('./img_features.csv', index_col=0)
img_feats.head()
# Out:
#          original_shape_Elongation  original_shape_Flatness  \
# patient
# 2                         0.738882                 0.723925
# 4                         0.796900                 0.629917
# 5                         0.600926                 0.535140
# 8                         0.784571                 0.414247
# 10                        0.690320                 0.539743
#
#          original_shape_LeastAxis  original_shape_MajorAxis  \
# patient
# 2                       27.060529                 37.380273
# 4                       19.845151                 31.504408
# 5                       22.515072                 42.073251
# 8                       30.263897                 73.057649
# 10                      19.449801                 36.035312
#
#          original_shape_Maximum2DDiameterColumn  \
# patient
# 2                                     41.976184
# 4                                     38.587563
# 5                                     46.065171
# 8                                     74.148500
# 10                                    33.286634
#
#          original_shape_Maximum2DDiameterRow  \
# patient
# 2                                  44.598206
# 4                                  35.468296
# 5                                  43.011626
# 8                                  80.956779
# 10                                 38.013156
#
#          original_shape_Maximum2DDiameterSlice  \
# patient
# 2                                    42.720019
# 4                                    29.410882
# 5                                    32.015621
# 8                                    65.764732
# 10                                   33.015148
#
#          original_shape_Maximum3DDiameter  original_shape_MinorAxis  \
# patient
# 2                               45.617979                 27.619612
# 4                               38.704005                 25.105855
# 5                               46.454279                 25.282894
# 8                               83.438600                 57.318945
# 10                              43.150898                 24.875896
#
#          original_shape_Sphericity     ...      \
# patient                                ...
# 2                         0.661532     ...
# 4                         0.701721     ...
# 5                         0.762365     ...
# 8                         0.520001     ...
# 10                        0.643822     ...
#
#          PET original_gldm_SmallDependenceHighGrayLevelEmphasis  \
# patient
# 2                                                 5.519092
# 4                                                 6.131197
# 5                                                 5.047617
# 8                                                 3.684029
# 10                                                4.875052
#
#          PET original_gldm_SmallDependenceLowGrayLevelEmphasis  \
# patient
# 2                                                 0.000475
# 4                                                 0.000615
# 5                                                 0.000795
# 8                                                 0.000522
# 10                                                0.000603
#
#          PET original_ngtdm_Busyness  PET original_ngtdm_Coarseness  \
# patient
# 2                           2.427090                       0.001254
# 4                           1.658665                       0.002416
# 5                           2.297591                       0.001332
# 8                           9.430757                       0.000576
# 10                          1.643871                       0.002969
#
#          PET original_ngtdm_Complexity  PET original_ngtdm_Contrast  \
# patient
# 2                            48.302361                     0.061505
# 4                            53.140323                     0.084396
# 5                            39.715808                     0.057499
# 8                            40.275824                     0.063654
# 10                           51.761539                     0.057269
#
#          PET original_ngtdm_Strength  PET SUVpeak  PET MTV     PET TLG
# patient
# 2                           0.456285    21.616549    7.384  124.870726
# 4                           0.697578    15.296275    3.406   41.554406
# 5                           0.450344    14.473272    7.934   86.228420
# 8                           0.098864    10.510859   26.926  205.413389
# 10                          0.473581     7.213190    6.041   32.103770
#
# [5 rows x 199 columns]

# %%
img_feats.shape
# Out:
# (198, 199)

# %%
clinical = pd.read_csv('./clinical_params.csv', index_col=0)
clinical.head()
# Out:
#                Age  Years Smoking  Naxogin Days  Sex_M  ICD-10_C02  \
# patient
# 2        60.832877       0.000000          39.0      1           0
# 4        49.906849       4.786027          33.0      0           0
# 5        54.238356       0.000000          42.0      0           0
# 8        54.687671      18.343836           0.0      1           0
# 10       61.728767       0.000000          35.0      1           0
#
#          ICD-10_C03  ICD-10_C04  ICD-10_C05  ICD-10_C06  ICD-10_C09   ...     \
# patient                                                               ...
# 2                 0           0           0           0           1   ...
# 4                 0           0           0           0           1   ...
# 5                 0           0           0           0           1   ...
# 8                 0           0           0           0           0   ...
# 10                0           0           0           0           0   ...
#
#          Cisplatin_1  Cisplatin_2  Cisplatin_3  Cisplatin_4  Cisplatin_5  \
# patient
# 2                  0            0            0            0            0
# 4                  0            0            0            0            1
# 5                  0            0            0            0            0
# 8                  0            0            1            0            0
# 10                 0            0            0            0            0
#
#          Cisplatin_6  Stage 1  Stage 2  Stage 3  Stage 4
# patient
# 2                  1        0        0        0        1
# 4                  0        0        0        0        1
# 5                  0        0        1        0        0
# 8                  0        0        0        0        1
# 10                 1        0        0        0        1
#
# [5 rows x 42 columns]

# %%
clinical.shape
# Out:
# (198, 42)

# %%
combined = pd.concat((img_feats, clinical), axis=1)

# %%
combined.shape
# Out:
# (198, 241)

# %%
# Sanity check for missing values.
combined.isnull().any().values.sum()
# Out:
# 0

# %%
combined.to_csv('./complete.csv')

# %% [markdown]
# ## Feature Decorrelation

# %%
# Correlation matrix
corr_mat = combined.corr().abs()

# %%
plt.figure(figsize=(14, 14))
axis = sns.heatmap(
    corr_mat, cmap=plt.cm.viridis, #xticklabels='', yticklabels=''
)
plt.tight_layout()
plt.savefig(
    './figures/feature_covar_mat.png',
    bbox_inches='tight',
    transparent=True,
    dpi=400, 
)

# %%
# Find index of feature columns with correlation greater than thresh
THRESH = 0.80

# Compute pairwise pearson correlation of columns
upper = corr_mat.where(
    np.triu(np.ones(corr_mat.shape), k=1).astype(np.bool)
)
to_drop = [column for column in upper.columns if any(upper[column] > THRESH)]
len(to_drop)
# Out:
# 144

# %%
to_drop
# Out:
# ['original_shape_Maximum2DDiameterColumn',
#  'original_shape_Maximum2DDiameterRow',
#  'original_shape_Maximum2DDiameterSlice',
#  'original_shape_Maximum3DDiameter',
#  'original_shape_MinorAxis',
#  'original_shape_SurfaceArea',
#  'original_shape_SurfaceVolumeRatio',
#  'original_shape_Volume',
#  'CT original_firstorder_Mean',
#  'CT original_firstorder_Median',
#  'CT original_firstorder_RobustMeanAbsoluteDeviation',
#  'CT original_firstorder_RootMeanSquared',
#  'CT original_firstorder_TotalEnergy',
#  'CT original_firstorder_Uniformity',
#  'CT original_firstorder_Variance',
#  'CT original_glcm_ClusterProminence',
#  'CT original_glcm_ClusterTendency',
#  'CT original_glcm_Contrast',
#  'CT original_glcm_DifferenceAverage',
#  'CT original_glcm_DifferenceEntropy',
#  'CT original_glcm_DifferenceVariance',
#  'CT original_glcm_Id',
#  'CT original_glcm_Idm',
#  'CT original_glcm_Idmn',
#  'CT original_glcm_Idn',
#  'CT original_glcm_Imc2',
#  'CT original_glcm_InverseVariance',
#  'CT original_glcm_JointAverage',
#  'CT original_glcm_JointEnergy',
#  'CT original_glcm_JointEntropy',
#  'CT original_glcm_MaximumProbability',
#  'CT original_glcm_SumAverage',
#  'CT original_glcm_SumEntropy',
#  'CT original_glcm_SumSquares',
#  'CT original_glrlm_GrayLevelNonUniformity',
#  'CT original_glrlm_GrayLevelNonUniformityNormalized',
#  'CT original_glrlm_GrayLevelVariance',
#  'CT original_glrlm_HighGrayLevelRunEmphasis',
#  'CT original_glrlm_LongRunEmphasis',
#  'CT original_glrlm_LongRunHighGrayLevelEmphasis',
#  'CT original_glrlm_LongRunLowGrayLevelEmphasis',
#  'CT original_glrlm_LowGrayLevelRunEmphasis',
#  'CT original_glrlm_RunEntropy',
#  'CT original_glrlm_RunLengthNonUniformityNormalized',
#  'CT original_glrlm_RunPercentage',
#  'CT original_glrlm_RunVariance',
#  'CT original_glrlm_ShortRunEmphasis',
#  'CT original_glrlm_ShortRunHighGrayLevelEmphasis',
#  'CT original_glrlm_ShortRunLowGrayLevelEmphasis',
#  'CT original_glszm_GrayLevelVariance',
#  'CT original_glszm_HighGrayLevelZoneEmphasis',
#  'CT original_glszm_LargeAreaEmphasis',
#  'CT original_glszm_LargeAreaHighGrayLevelEmphasis',
#  'CT original_glszm_LargeAreaLowGrayLevelEmphasis',
#  'CT original_glszm_LowGrayLevelZoneEmphasis',
#  'CT original_glszm_SizeZoneNonUniformity',
#  'CT original_glszm_SmallAreaLowGrayLevelEmphasis',
#  'CT original_glszm_ZoneEntropy',
#  'CT original_glszm_ZoneVariance',
#  'CT original_gldm_DependenceEntropy',
#  'CT original_gldm_DependenceNonUniformity',
#  'CT original_gldm_DependenceNonUniformityNormalized',
#  'CT original_gldm_DependenceVariance',
#  'CT original_gldm_GrayLevelNonUniformity',
#  'CT original_gldm_GrayLevelVariance',
#  'CT original_gldm_HighGrayLevelEmphasis',
#  'CT original_gldm_LargeDependenceEmphasis',
#  'CT original_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'CT original_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'CT original_gldm_LowGrayLevelEmphasis',
#  'CT original_gldm_SmallDependenceEmphasis',
#  'CT original_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'CT original_gldm_SmallDependenceLowGrayLevelEmphasis',
#  'CT original_ngtdm_Complexity',
#  'PET original_firstorder_Energy',
#  'PET original_firstorder_Entropy',
#  'PET original_firstorder_Maximum',
#  'PET original_firstorder_MeanAbsoluteDeviation',
#  'PET original_firstorder_Median',
#  'PET original_firstorder_Range',
#  'PET original_firstorder_RobustMeanAbsoluteDeviation',
#  'PET original_firstorder_RootMeanSquared',
#  'PET original_firstorder_Skewness',
#  'PET original_firstorder_TotalEnergy',
#  'PET original_firstorder_Uniformity',
#  'PET original_firstorder_Variance',
#  'PET original_glcm_ClusterProminence',
#  'PET original_glcm_ClusterTendency',
#  'PET original_glcm_Correlation',
#  'PET original_glcm_DifferenceAverage',
#  'PET original_glcm_DifferenceEntropy',
#  'PET original_glcm_DifferenceVariance',
#  'PET original_glcm_Id',
#  'PET original_glcm_Idm',
#  'PET original_glcm_Idn',
#  'PET original_glcm_Imc2',
#  'PET original_glcm_InverseVariance',
#  'PET original_glcm_JointAverage',
#  'PET original_glcm_JointEnergy',
#  'PET original_glcm_JointEntropy',
#  'PET original_glcm_MaximumProbability',
#  'PET original_glcm_SumAverage',
#  'PET original_glcm_SumEntropy',
#  'PET original_glcm_SumSquares',
#  'PET original_glrlm_GrayLevelNonUniformity',
#  'PET original_glrlm_GrayLevelNonUniformityNormalized',
#  'PET original_glrlm_GrayLevelVariance',
#  'PET original_glrlm_HighGrayLevelRunEmphasis',
#  'PET original_glrlm_LongRunEmphasis',
#  'PET original_glrlm_LongRunHighGrayLevelEmphasis',
#  'PET original_glrlm_RunEntropy',
#  'PET original_glrlm_RunLengthNonUniformity',
#  'PET original_glrlm_RunPercentage',
#  'PET original_glrlm_RunVariance',
#  'PET original_glrlm_ShortRunEmphasis',
#  'PET original_glrlm_ShortRunHighGrayLevelEmphasis',
#  'PET original_glrlm_ShortRunLowGrayLevelEmphasis',
#  'PET original_glszm_HighGrayLevelZoneEmphasis',
#  'PET original_glszm_LargeAreaEmphasis',
#  'PET original_glszm_LargeAreaHighGrayLevelEmphasis',
#  'PET original_glszm_LargeAreaLowGrayLevelEmphasis',
#  'PET original_glszm_SizeZoneNonUniformity',
#  'PET original_glszm_SmallAreaEmphasis',
#  'PET original_glszm_SmallAreaHighGrayLevelEmphasis',
#  'PET original_glszm_SmallAreaLowGrayLevelEmphasis',
#  'PET original_glszm_ZoneVariance',
#  'PET original_gldm_DependenceEntropy',
#  'PET original_gldm_DependenceNonUniformity',
#  'PET original_gldm_DependenceNonUniformityNormalized',
#  'PET original_gldm_DependenceVariance',
#  'PET original_gldm_GrayLevelNonUniformity',
#  'PET original_gldm_GrayLevelVariance',
#  'PET original_gldm_HighGrayLevelEmphasis',
#  'PET original_gldm_LargeDependenceEmphasis',
#  'PET original_gldm_LargeDependenceHighGrayLevelEmphasis',
#  'PET original_gldm_LargeDependenceLowGrayLevelEmphasis',
#  'PET original_gldm_LowGrayLevelEmphasis',
#  'PET original_gldm_SmallDependenceEmphasis',
#  'PET original_gldm_SmallDependenceHighGrayLevelEmphasis',
#  'PET original_ngtdm_Busyness',
#  'PET original_ngtdm_Complexity',
#  'PET MTV',
#  'PET TLG',
#  'HPV_2']

# %%
def radional_difference(original, num, denom):
    # Rational difference transformation.
    num_feat = combined[num[0]]
    for feat in num[1:]:
        num_feat -= original[feat]

    denom_feat = original[denom[0]]
    for feat in denom[1:]:
        denom_feat -= original[feat]
    
    return num_feat / denom_feat

# %%
num, denom = to_drop[:int(len(to_drop) / 2)], to_drop[int(len(to_drop) / 2):]
len(num) + len(denom), len(to_drop)
# Out:
# (144, 144)

# %%
combined['forward_corr'] = radional_difference(combined, num, denom)

# %%
combined['backward_corr'] = radional_difference(combined, denom, num)

# %%
combined.shape
# Out:
# (198, 243)

# %%
combined.drop(to_drop, axis=1, inplace=True)

# %%
combined.shape
# Out:
# (198, 99)

# %%
# Correlation matrix
corr_mat = combined.corr().abs()
plt.figure(figsize=(14, 14))
axis = sns.heatmap(
    corr_mat, cmap=plt.cm.viridis, #xticklabels='', yticklabels=''
)
plt.tight_layout()
plt.savefig(
    './figures/filtered_feature_covar_mat.png',
    bbox_inches='tight',
    transparent=True,
    dpi=400, 
)

# %%
combined.to_csv('./complete_decorr.csv')
