# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Original Images Features

# %%
orig_img_feats = pd.read_csv(
    './../../data_source/to_analysis/original_images/all_features_original_images.csv',
    index_col=0
)
orig_img_feats.head()
# Out:
#           Age  Years Smoking  Naxogin Days  Sex_M  ICD-10_C02  ICD-10_C03  \
# 2   60.832877       0.000000          39.0      1           0           0
# 4   49.906849       4.786027          33.0      0           0           0
# 5   54.238356       0.000000          42.0      0           0           0
# 8   54.687671      18.343836           0.0      1           0           0
# 10  61.728767       0.000000          35.0      1           0           0
#
#     ICD-10_C04  ICD-10_C05  ICD-10_C06  ICD-10_C09      ...       \
# 2            0           0           0           1      ...
# 4            0           0           0           1      ...
# 5            0           0           0           1      ...
# 8            0           0           0           0      ...
# 10           0           0           0           0      ...
#
#     PET_original_ngtdm_Complexity_128bins  PET_original_ngtdm_Contrast_32bins  \
# ...

# %%
orig_img_feats_corr_mat = orig_img_feats.corr().abs()

# %%
plt.figure(figsize=(8, 8))
sns.heatmap(
   orig_img_feats_corr_mat 
)
#plt.tight_layout()
plt.axis('off')
# Out:
# (0.0, 391.0, 391.0, 0.0)

# %% [markdown]
# ## Hassan Transformed Original Images Features

# %%
orig_img_feats = pd.read_csv(
    './../../data_source/to_analysis/original_images/hassan_all_features_original_images.csv',
    index_col=0
)
orig_img_feats.head()
# Out:
#     CT_original_glcm_Autocorrelation_32bins  \
# 2                                 15.835837
# 4                                 11.917136
# 5                                 23.695404
# 8                                 34.895257
# 10                                15.917349
#
#     CT_original_glcm_Autocorrelation_64bins  \
# 2                                 48.879403
# 4                                 40.804717
# 5                                 63.013916
# 8                                118.113705
# 10                                48.319152
#
#     CT_original_glcm_Autocorrelation_128bins  \
# 2                                 159.175192
# 4                                 150.846648
# 5                                 231.810872
# 8                                 450.544195
# 10                                163.419029
#
#     CT_original_glcm_ClusterProminence_32bins  \
# 2                                    0.568382
# 4                                    2.494158
# ...
