# %% [markdown]
# **Objective:**
#
# Compare dependence of first order and texture features on image artifact hadling method:
# * Calculate features from original images.
# * Remove slices before calculating first order and texture features.

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Comparing First Order Features

# %%
x_original_images = pd.read_csv(
    './../../data_source/to_analysis/original_images/firstorder_original_images.csv',
    index_col=0
)
firstorder_original_images.head()
# Out:
#     CT_original_firstorder_10Percentile  CT_original_firstorder_90Percentile  \
# 2                           1064.381323                          1115.994507
# 4                            972.027466                          1183.041657
# 5                           1030.239139                          1177.917830
# 8                           1028.577020                          1085.938888
# 10                          1054.821012                          1099.248341
#
#     CT_original_firstorder_Energy  CT_original_firstorder_Entropy_32bins  \
# 2                    2.027206e+10                               0.880520
# 4                    1.149213e+10                               1.778598
# 5                    1.989521e+10                               1.426984
# 8                    7.735412e+10                               1.250193
# 10                   1.240511e+10                               1.091973
#
#     CT_original_firstorder_Entropy_64bins  \
# 2                                1.214331
# 4                                2.664314
# 5                                2.245106
# 8                                1.527644
# 10                               1.266005
#
#     CT_original_firstorder_Entropy_128bins  \
# 2                                 1.984033
# 4                                 3.638895
# 5                                 3.204547
# 8                                 2.067914
# 10                                1.745669
#
#     CT_original_firstorder_InterquartileRange  \
# 2                                   23.619593
# 4                                   79.044404
# 5                                   45.224022
# 8                                   22.494850
# 10                                  17.745937
#
#     CT_original_firstorder_Kurtosis  CT_original_firstorder_Maximum  \
# 2                         59.779383                     1450.980316
# 4                          8.933352                     1414.363699
# 5                         14.831983                     1763.283818
# 8                         55.850257                     1534.148775
# 10                        46.402736                     1364.937514
#
#     CT_original_firstorder_Mean  ...  PET_original_firstorder_Minimum  \
# 2                   1086.644460  ...                         1.204310
# 4                   1086.186295  ...                         1.433140
# 5                   1104.664236  ...                         1.163221
# 8                   1053.427788  ...                         0.743620
# 10                  1072.696565  ...                         0.982504
#
#     PET_original_firstorder_Range  \
# 2                       23.536890
# 4                       17.222283
# 5                       15.576279
# 8                       13.467292
# 10                       7.810330
#
#     PET_original_firstorder_RobustMeanAbsoluteDeviation  \
# 2                                            4.557986
# 4                                            2.971142
# 5                                            2.608982
# 8                                            1.678665
# 10                                           1.009663
#
#     PET_original_firstorder_RootMeanSquared  PET_original_firstorder_Skewness  \
# 2                                 12.223637                          0.417061
# 4                                  8.148343                          0.854620
# 5                                  8.423547                          0.269824
# 8                                  5.486017                          0.616056
# 10                                 4.466349                          0.484758
#
#     PET_original_firstorder_TotalEnergy  \
# 2                          2.561311e+06
# 4                          6.414469e+05
# 5                          1.150483e+06
# 8                          2.087304e+06
# 10                         2.144240e+05
#
#     PET_original_firstorder_Uniformity_32bins  \
# 2                                    0.024358
# 4                                    0.050900
# 5                                    0.033659
# 8                                    0.055394
# 10                                   0.078781
#
#     PET_original_firstorder_Uniformity_64bins  \
# 2                                    0.012234
# 4                                    0.025867
# 5                                    0.016863
# 8                                    0.027849
# 10                                   0.039523
#
#     PET_original_firstorder_Uniformity_128bins  \
# 2                                     0.006143
# 4                                     0.013045
# 5                                     0.008454
# 8                                     0.013958
# 10                                    0.019812
#
#     PET_original_firstorder_Variance
# 2                          40.888750
# 4                          20.679742
# 5                          14.867608
# 8                           6.898970
# 10                          2.722132
#
# [5 rows x 44 columns]

# %%
# TODO: 
# Plot variance between first order feature sets calculated after different image processing techniques.

# %% [markdown]
# # Comparing Texture Features

# %%
texture_original_images = pd.read_csv(
    './../../data_source/to_analysis/original_images/texture_original_images.csv',
    index_col=0
)

# %%
# TODO: 
# Plot variance between texture feature sets calculated after different image processing techniques.
